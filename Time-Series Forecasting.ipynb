# %%
import numpy as np # numerical python
import pandas as pd # pannel datasets
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# load the data using pandas
df = pd.read_excel('D:/7. JUL - DEC 2021/TEDP/Data Science Course/Debourgh-Sales.xlsx',sheet_name='Sheet2', engine='openpyxl')
df.head()
# Out:
#        Years  Sales  Unnamed: 2
# 0 2001-01-01  139.7         NaN
# 1 2001-02-01  114.3         NaN
# 2 2001-03-01  101.6         NaN
# 3 2001-04-01  152.4         NaN
# 4 2001-05-01  215.9         NaN

# %%
plt.figure(figsize=(15,6))
plsns.lineot(x='Years',y='Sales',data=df)
plt.show()

# %%
df1 = df.set_index('Years') # setting "Years" as index
fig,ax = plt.subplots(figsize=(15,6))
df1.plot(kind='line',ax=ax)
plt.show()

# %%
df['year'] = df['Years'].dt.year  # extracting year
df['quarter'] = df['Years'].dt.quarter # extracting quarter
df.head()
# Out:
#        Years  Sales  Unnamed: 2  year  quarter
# 0 2001-01-01  139.7         NaN  2001        1
# 1 2001-02-01  114.3         NaN  2001        1
# 2 2001-03-01  101.6         NaN  2001        1
# 3 2001-04-01  152.4         NaN  2001        2
# 4 2001-05-01  215.9         NaN  2001        2

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Years',y='Sales',data=df,hue='year',palette='Set1')
plt.show()

# %% [markdown]
# # bar plot

# %%
df_year = df[['Sales','year']].groupby(by='year').sum().reset_index()
df_year
# Out:
#    year   Sales
# 0  2001  1968.5
# 1  2002  2577.8
# 2  2003  3136.9
# 3  2004  3947.8
# 4  2005  5080.0
# 5  2006  6045.2
# 6  2007  5791.2
# 7  2008  6642.1
# 8  2009  8000.7

# %%
sns.catplot(x='year',y='Sales',data=df_year,kind='bar',aspect=3)

# %%
fig, ax = plt.subplots(figsize=(15,6))
df_year.set_index('year').plot(kind='bar',ax=ax)
plt.show()

# %%
sales = df[['Sales','year','quarter']].groupby(by=['year','quarter']).sum().values
df_sales = pd.DataFrame(sales.reshape(9,4),index=list(range(2001,2010)),columns=           ['Q1','Q2','Q3','Q4'])fig,ax = plt.subplots(figsize=(15,6))
df_sales.plot(kind='bar',ax=ax,stacked=True)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(15,6))
df_sales.plot(kind='bar',ax=ax)
plt.show()

# %% [markdown]
# # area plot

# %%
fig,ax = plt.subplots(figsize=(15,6))
df1.plot(kind='area',ax=ax)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(15,6))
df_sales.plot(kind='area',ax=ax,stacked=True)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(15,6))
df_sales.plot(kind='area',ax=ax,stacked=False)
plt.show()

# %% [markdown]
# # heat map

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_sales,annot=True,fmt='.2f',cmap='gnuplot',linewidths=1)
plt.show()
